# %%
import numpy as np #2.2.1
import cv2 #4.10.0.84
import os
from natsort import natsorted
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
#OCR Framework
import pytesseract
from paddleocr import PaddleOCR
import paddle
import easyocr

#OCR Metrics
from jiwer import wer, cer
import time

# %%
print("PaddlePaddle device:", paddle.device.get_device())
# Out:
# PaddlePaddle device: cpu

# %% [markdown]
# Pytesseract, PaddleOCR, EasyOCR
# Metrics used: CER(Character Error Rate), WER(Word Error Rate), EMA(Exact Match Accuracy)

# %%
def parse_label_files(label_folder, num_files):
    annotations = {}
    label_files = natsorted(os.listdir(label_folder))[:num_files]  # Take only the specified number of files
    for label_file in label_files:
        file_path = os.path.join(label_folder, label_file)
        with open(file_path, 'r') as file:
            annotation = []
            for line in file:
                data = line.strip().split(',')
                coords = list(map(int, data[:8]))  # First 8 values are bounding box coordinates
                text = data[8]  # The 9th value is the text
                annotation.append((coords, text))
        annotations[label_file] = annotation
    return annotations

def draw_boxes(image_folder, label_folder, num_files, font_path="/usr/share/fonts/truetype/noto/NotoSans-Regular.ttf", font_size = 16):
    annotations = parse_label_files(label_folder, num_files)
    label_files = sorted(annotations.keys())  # Ensure labels are sorted in the right order

    for i, label_file in enumerate(label_files):
        # Generate the corresponding image name starting from "im0001.jpg"
        image_file = f"im{i + 1:04d}.jpg"  # Format index with leading zeros (e.g., im0001.jpg)
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        # Read and draw bounding boxes on the image
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Convert to a Pillow Image
        pil_image = Image.fromarray(image)
        draw = ImageDraw.Draw(pil_image)

        # Load the Noto Sans font
        font = ImageFont.truetype(font_path, font_size)

        # Draw bounding boxes and text
        for coords, text in annotations[label_file]:
            pts = [(coords[i], coords[i + 1]) for i in range(0, len(coords), 2)]
            draw.polygon(pts, outline="green", width=2)
            draw.text((pts[0][0], pts[0][1] - font_size), text, fill="green", font=font)

        # Convert back to OpenCV format
        image = np.array(pil_image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Display the image
        cv2.imshow(f"Image: {image_file}", image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
def crop_text_regions(image, coords):
    """Crop text regions using bounding box coordinates."""
    pts = np.array(coords, dtype=np.int32).reshape((4, 2))
    rect = cv2.boundingRect(pts)
    x, y, w, h = rect
    cropped = image[y:y+h, x:x+w]
    return cropped

# %%
def apply_easyocr(image_folder, label_folder, num_files):
    reader = easyocr.Reader(['en', 'vi'])  # Adjust languages as needed
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)
            result = reader.readtext(cropped)
            predicted_text = result[0][-2] if result else ""
            print(f"True: {true_text}, Predicted (EasyOCR): {predicted_text}")

# %%
def apply_paddleocr(image_folder, label_folder, num_files):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Adjust language if needed
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)

            # Process the cropped image directly without saving
            result = ocr.ocr(cropped, det=False)
            print("OCR result:", result)  # Debugging: Print the result

            # Handle invalid result structures
            if isinstance(result, list) and len(result) > 0 and isinstance(result[0], list):
                # Extract text from valid result structure
                try:
                    predicted_text = result[0][0][1][0]  # Extract detected text
                except (IndexError, TypeError):
                    predicted_text = ""  # Fallback for invalid structure
            else:
                predicted_text = ""  # Handle cases where result is not as expected

            print(f"True: {true_text}, Predicted (PaddleOCR): {predicted_text}")

# %%
def apply_tesseractocr(image_folder, label_folder, num_files):
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)
            predicted_text = pytesseract.image_to_string(cropped, lang='eng')
            print(f"True: {true_text}, Predicted (TesseractOCR): {predicted_text.strip()}")

# %%
# Calculate runtime and metrics
easyocr_reader = easyocr.Reader(["en", "vi"])  # EasyOCR
paddle_ocr = PaddleOCR(use_angle_cls=True, lang="en")  # PaddleOCR

def calculate_metrics(ocr_framework, image_folder, label_folder, num_files):
    annotations = parse_label_files(label_folder, num_files)
    runtimes = []
    cer_list = []
    wer_list = []
    exact_matches = 0

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found: {image_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)

            # Measure runtime
            start_time = time.time()
            if ocr_framework == "easyocr":
                result = easyocr_reader.readtext(cropped)
                predicted_text = result[0][-2] if result else ""
            elif ocr_framework == "paddleocr":
                # Process the cropped image directly without saving
                result = paddle_ocr.ocr(cropped, det=False)
                print(result)  # Debugging: Print the result structure
                try:
                    if result and isinstance(result[0], list) and result[0]:
                        predicted_text = result[0][0][1][0]  # Extract text
                    else:
                        predicted_text = ""
                except (IndexError, TypeError):
                    predicted_text = ""
            elif ocr_framework == "tesseract":
                predicted_text = pytesseract.image_to_string(cropped, lang="eng").strip()
            else:
                raise ValueError("Invalid OCR framework")
            end_time = time.time()

            # Update metrics
            runtimes.append(end_time - start_time)
            cer_list.append(cer(true_text, predicted_text))
            wer_list.append(wer(true_text, predicted_text))
            if true_text == predicted_text:
                exact_matches += 1

    # Aggregate results
    avg_runtime = np.mean(runtimes)
    avg_cer = np.mean(cer_list) * 100  # Convert to percentage
    avg_wer = np.mean(wer_list) * 100  # Convert to percentage
    exact_match_accuracy = (exact_matches / sum(len(ann) for ann in annotations.values())) * 100

    return {
        "Framework": ocr_framework,
        "Avg Runtime (s)": avg_runtime,
        "Avg CER (%)": avg_cer,
        "Avg WER (%)": avg_wer,
        "Exact Match Accuracy (%)": exact_match_accuracy,
    }
# Out:
# [2024/12/24 11:40:42] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/nhduong141103/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/nhduong141103/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/nhduong141103/VegaCop/OCR/OCR/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/nhduong141103/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
image_folder = "/home/nhduong141103/VegaCop/OCR/OCR_project/ocr-dataset-20241224/images/"
label_folder = "/home/nhduong141103/VegaCop/OCR/OCR_project/ocr-dataset-20241224/labels/"
font_path = "/usr/share/fonts/truetype/noto/NotoSans-Regular.ttf"

#draw_boxes(image_folder, label_folder, 5, font_path = font_path, font_size = 20)

# Number of files to process
num_files = 5

# Apply EasyOCR
apply_easyocr(image_folder, label_folder, num_files) #Working

# Apply PaddleOCR
apply_paddleocr(image_folder, label_folder, num_files) #Working

# Apply TesseractOCR
apply_tesseractocr(image_folder, label_folder, num_files) #Working

# Calculate metrics
results_easyocr = calculate_metrics("easyocr", image_folder, label_folder, num_files)
results_paddleocr = calculate_metrics("paddleocr", image_folder, label_folder, num_files)
results_tesseract = calculate_metrics("tesseract", image_folder, label_folder, num_files)

results_df = pd.DataFrame([results_easyocr, results_paddleocr, results_tesseract])
print(results_df)
# Out:
# True: ###, Predicted (EasyOCR):
# True: CHẤT, Predicted (EasyOCR): OH
# True: LƯỢNG, Predicted (EasyOCR): WUI
# True: TỐT, Predicted (EasyOCR):
# True: ĐỂ, Predicted (EasyOCR):
# True: CÓ, Predicted (EasyOCR):
# True: VIỆC, Predicted (EasyOCR): VEC
# True: LÀM, Predicted (EasyOCR):
# True: NĂNG, Predicted (EasyOCR): HiN
# True: SUẤT, Predicted (EasyOCR): SV]
# True: CAO, Predicted (EasyOCR): 6
# True: ĐỂ, Predicted (EasyOCR):
# True: TĂNG, Predicted (EasyOCR): TINA
# True: THU, Predicted (EasyOCR):
# True: NHẬP, Predicted (EasyOCR): HKAP
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CỔNG, Predicted (EasyOCR): CỔNG
# True: TRƯỜNG, Predicted (EasyOCR): TRUÒNG
# True: AN, Predicted (EasyOCR): AN
# True: TOÀN, Predicted (EasyOCR): TOÀN
# True: GIAO, Predicted (EasyOCR): GIAO
# True: THÔNG, Predicted (EasyOCR): THONG
# True: Dừng, Predicted (EasyOCR): Dùng
# True: lại, Predicted (EasyOCR): lai
# True: quan, Predicted (EasyOCR): quan
# True: sát, Predicted (EasyOCR): sát
# True: trước, Predicted (EasyOCR): trưóc
# True: khi, Predicted (EasyOCR): khi
# True: qua, Predicted (EasyOCR): qua
# True: đường, Predicted (EasyOCR): đuòng
# True: ###, Predicted (EasyOCR):
# True: Ngân, Predicted (EasyOCR):
# True: hàn, Predicted (EasyOCR):
# True: Vie, Predicted (EasyOCR): Vie
# True: Ch, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: TRƯỜNG, Predicted (EasyOCR):
# True: ĐANG, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: TRƯỜNG, Predicted (EasyOCR):
# True: BÃI, Predicted (EasyOCR): BÃl
# True: GỬI, Predicted (EasyOCR): GU
# True: XE, Predicted (EasyOCR): XE
# True: HÃY, Predicted (EasyOCR): HÃY
# True: NGĂN, Predicted (EasyOCR): NGĂN
# True: CHẶN, Predicted (EasyOCR): CHẶN
# True: NẠN, Predicted (EasyOCR): NAN
# True: BUÔN, Predicted (EasyOCR): BUÔN
# True: BÁN, Predicted (EasyOCR): BÁN
# True: PHỤ, Predicted (EasyOCR): PHỤ
# True: NỮ, Predicted (EasyOCR): NỮ
# True: VÀ, Predicted (EasyOCR): VÀ
# True: TRẺ, Predicted (EasyOCR): TRẺ
# True: EM, Predicted (EasyOCR): EM
# True: NHÀ, Predicted (EasyOCR): K
# True: THUỐC, Predicted (EasyOCR): 2É
# True: PHARMACY, Predicted (EasyOCR): Picl
# True: iệt, Predicted (EasyOCR): iêt
# True: Bảo, Predicted (EasyOCR): Bảo
# True: Bảo, Predicted (EasyOCR): Bảo
# True: vệ, Predicted (EasyOCR): Vệ
# True: sức, Predicted (EasyOCR): Súc
# True: khoẻ, Predicted (EasyOCR): khoẻ
# True: người, Predicted (EasyOCR): nguời
# True: Việt, Predicted (EasyOCR): Việt
# True: DSPT:, Predicted (EasyOCR): DSPT:
# True: NGUYỄN, Predicted (EasyOCR): NGUYÊN
# True: VĂN, Predicted (EasyOCR): VĂI]
# True: DỤNG, Predicted (EasyOCR): DUIG
# True: GPS:, Predicted (EasyOCR): GFS:
# True: ĐC:, Predicted (EasyOCR): DC:
# True: 30, Predicted (EasyOCR): 30
# True: LƯƠNG, Predicted (EasyOCR): LUONG
# True: YÊN, Predicted (EasyOCR): VÊN
# True: -, Predicted (EasyOCR):
# True: P., Predicted (EasyOCR): P
# True: BẠCH, Predicted (EasyOCR): BACH
# True: ĐẰNG, Predicted (EasyOCR): DĂNIG
# True: -, Predicted (EasyOCR):
# True: Q., Predicted (EasyOCR): 0
# True: HAI, Predicted (EasyOCR): HAI
# True: BÀ, Predicted (EasyOCR): BA
# True: TRƯNG, Predicted (EasyOCR): TRUIG
# True: HÀ, Predicted (EasyOCR): HA
# True: NỘI, Predicted (EasyOCR): Noi
# True: ĐT:, Predicted (EasyOCR): DT:
# True: 0968656003, Predicted (EasyOCR): 0968 656 003
# True: NHÀ, Predicted (EasyOCR): NHÀ
# True: THUỐC, Predicted (EasyOCR): ThUỐc
# True: VIỆT, Predicted (EasyOCR): VIÊT
# True: BẢO, Predicted (EasyOCR): BẢO
# True: Tết, Predicted (EasyOCR): Tet
# True: sum, Predicted (EasyOCR): SUm
# True: vầy, Predicted (EasyOCR): vày
# True: đong, Predicted (EasyOCR): dong
# True: đầy, Predicted (EasyOCR): Gay
# True: Điểm, Predicted (EasyOCR): Dlem
# True: thưởng, Predicted (EasyOCR): churong
# True: Chương, Predicted (EasyOCR): Chuong
# True: trình, Predicted (EasyOCR): trinn
# True: tích, Predicted (EasyOCR): Uen
# True: và, Predicted (EasyOCR):
# True: tiêu, Predicted (EasyOCR): Lcu
# True: điểm, Predicted (EasyOCR): Dlem
# True: thưởng, Predicted (EasyOCR): thuong
# True: trên, Predicted (EasyOCR): tren
# True: mỗi, Predicted (EasyOCR): mo1
# True: hoá, Predicted (EasyOCR): n62
# True: đơn, Predicted (EasyOCR): dan
# True: mua, Predicted (EasyOCR): Ca
# True: hàng, Predicted (EasyOCR): hàng
# True: ƯỚT, Predicted (EasyOCR): UO7
# True: ###, Predicted (EasyOCR): SAT
# True: ###, Predicted (EasyOCR): GHô
# True: 30, Predicted (EasyOCR): 30
# True: LƯƠ, Predicted (EasyOCR): LƯO
# True: NHÀ, Predicted (EasyOCR):
# True: THUỐC, Predicted (EasyOCR):
# True: MỸ, Predicted (EasyOCR):
# True: PHẨM, Predicted (EasyOCR): V
# True: ###, Predicted (EasyOCR):
# True: CAO, Predicted (EasyOCR): G
# True: SU, Predicted (EasyOCR): 4
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ĐOẠN, Predicted (EasyOCR): OOAN
# True: ĐƯỜNG, Predicted (EasyOCR): OuOhG
# True: TỰ, Predicted (EasyOCR): TU
# True: QUẢN, Predicted (EasyOCR): QUAh
# True: 2, Predicted (EasyOCR): 2
# True: KHÔNG, Predicted (EasyOCR): HhoNG
# [2024/12/24 11:40:47] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/nhduong141103/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/nhduong141103/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/nhduong141103/VegaCop/OCR/OCR/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/nhduong141103/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# OCR result: [[('HOF', 0.7248262763023376)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('CHAT', 0.9970598220825195)]]
# True: CHẤT, Predicted (PaddleOCR):
# OCR result: [[('LUONG', 0.8340489268302917)]]
# True: LƯỢNG, Predicted (PaddleOCR):
# OCR result: [[('TOT', 0.6198198795318604)]]
# True: TỐT, Predicted (PaddleOCR):
# OCR result: [[('DE', 0.9875959157943726)]]
# True: ĐỂ, Predicted (PaddleOCR):
# OCR result: [[('CO', 0.7626323699951172)]]
# True: CÓ, Predicted (PaddleOCR):
# OCR result: [[('VIEC', 0.827197253704071)]]
# True: VIỆC, Predicted (PaddleOCR):
# OCR result: [[('LAM,', 0.8659693598747253)]]
# True: LÀM, Predicted (PaddleOCR):
# OCR result: [[('NANG', 0.9824891090393066)]]
# True: NĂNG, Predicted (PaddleOCR):
# OCR result: [[('SUAT', 0.9761183261871338)]]
# True: SUẤT, Predicted (PaddleOCR):
# OCR result: [[('CAO', 0.9812984466552734)]]
# True: CAO, Predicted (PaddleOCR):
# OCR result: [[('DE', 0.9742392301559448)]]
# True: ĐỂ, Predicted (PaddleOCR):
# OCR result: [[('TANG', 0.9967201948165894)]]
# True: TĂNG, Predicted (PaddleOCR):
# OCR result: [[('THU', 0.9941852688789368)]]
# True: THU, Predicted (PaddleOCR):
# OCR result: [[('NHAP', 0.8980079889297485)]]
# True: NHẬP, Predicted (PaddleOCR):
# OCR result: [[('am', 0.5149505138397217)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('a0', 0.11906231194734573)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('-', 0.35519713163375854)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('', 0.0)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('C', 0.12205097079277039)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('i', 0.2419385313987732)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('2', 0.15024158358573914)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('O', 0.21958497166633606)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('n', 0.2101198434829712)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('TER', 0.28574568033218384)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('LS', 0.3546040654182434)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('O', 0.1922067105770111)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('TIEr', 0.6346054077148438)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('I', 0.2683390974998474)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('S02E', 0.2676371932029724)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('CONG', 0.996503472328186)]]
# True: CỔNG, Predicted (PaddleOCR):
# OCR result: [[('TRUONG', 0.9205740094184875)]]
# True: TRƯỜNG, Predicted (PaddleOCR):
# OCR result: [[('AN', 0.9973358511924744)]]
# True: AN, Predicted (PaddleOCR):
# OCR result: [[('TOAN', 0.9981263279914856)]]
# True: TOÀN, Predicted (PaddleOCR):
# OCR result: [[('GIAO', 0.9927723407745361)]]
# True: GIAO, Predicted (PaddleOCR):
# OCR result: [[('THONG', 0.9980703592300415)]]
# True: THÔNG, Predicted (PaddleOCR):
# OCR result: [[('Dung', 0.9720937013626099)]]
# True: Dừng, Predicted (PaddleOCR):
# OCR result: [[('lai', 0.9779927134513855)]]
# True: lại, Predicted (PaddleOCR):
# OCR result: [[('quan', 0.9973017573356628)]]
# True: quan, Predicted (PaddleOCR):
# OCR result: [[('sat', 0.9958863854408264)]]
# True: sát, Predicted (PaddleOCR):
# OCR result: [[('truoc', 0.9935256838798523)]]
# True: trước, Predicted (PaddleOCR):
# OCR result: [[('khi', 0.9907448291778564)]]
# True: khi, Predicted (PaddleOCR):
# OCR result: [[('enb', 0.9869994521141052)]]
# True: qua, Predicted (PaddleOCR):
# OCR result: [[('duong', 0.9985593557357788)]]
# True: đường, Predicted (PaddleOCR):
# OCR result: [[('BAN', 0.9491246342658997)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('Ngan', 0.7521347403526306)]]
# True: Ngân, Predicted (PaddleOCR):
# OCR result: [[('han', 0.8118379712104797)]]
# True: hàn, Predicted (PaddleOCR):
# OCR result: [[('VIe', 0.8804585337638855)]]
# True: Vie, Predicted (PaddleOCR):
# OCR result: [[('Ch', 0.9899793863296509)]]
# True: Ch, Predicted (PaddleOCR):
# OCR result: [[('COND', 0.9215390086174011)]]
# True: CÔNG, Predicted (PaddleOCR):
# OCR result: [[('IRUONG', 0.7666494250297546)]]
# True: TRƯỜNG, Predicted (PaddleOCR):
# OCR result: [[('SANG', 0.7818746566772461)]]
# True: ĐANG, Predicted (PaddleOCR):
# OCR result: [[('8', 0.07697561383247375)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('LONG', 0.807560920715332)]]
# True: CÔNG, Predicted (PaddleOCR):
# OCR result: [[('CAM', 0.9569395184516907)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('o', 0.12506254017353058)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('T', 0.7708498239517212)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('ROA', 0.3235209882259369)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('ERAM', 0.6682843565940857)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('U', 0.1302759349346161)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('SHE', 0.4318881332874298)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('RO', 0.4087999165058136)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('TON', 0.9173479676246643)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('OUAY', 0.7586358785629272)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('CONO', 0.5619122982025146)]]
# True: CÔNG, Predicted (PaddleOCR):
# OCR result: [[('TEUONG', 0.6592857241630554)]]
# True: TRƯỜNG, Predicted (PaddleOCR):
# OCR result: [[('BAI', 0.9373375773429871)]]
# True: BÃI, Predicted (PaddleOCR):
# OCR result: [[('GU', 0.7155078649520874)]]
# True: GỬI, Predicted (PaddleOCR):
# OCR result: [[('XE', 0.996226966381073)]]
# True: XE, Predicted (PaddleOCR):
# OCR result: [[('HAY', 0.9933437705039978)]]
# True: HÃY, Predicted (PaddleOCR):
# OCR result: [[('NGAN', 0.9974562525749207)]]
# True: NGĂN, Predicted (PaddleOCR):
# OCR result: [[('CHAN', 0.9962782859802246)]]
# True: CHẶN, Predicted (PaddleOCR):
# OCR result: [[('NAN', 0.9974414706230164)]]
# True: NẠN, Predicted (PaddleOCR):
# OCR result: [[('BUON', 0.9970767498016357)]]
# True: BUÔN, Predicted (PaddleOCR):
# OCR result: [[('BAN', 0.9965600371360779)]]
# True: BÁN, Predicted (PaddleOCR):
# OCR result: [[('PHU', 0.9259838461875916)]]
# True: PHỤ, Predicted (PaddleOCR):
# OCR result: [[('AN', 0.7066661715507507)]]
# True: NỮ, Predicted (PaddleOCR):
# OCR result: [[('VA', 0.9889934062957764)]]
# True: VÀ, Predicted (PaddleOCR):
# OCR result: [[('TRE', 0.9959554672241211)]]
# True: TRẺ, Predicted (PaddleOCR):
# OCR result: [[('EM', 0.9953380823135376)]]
# True: EM, Predicted (PaddleOCR):
# OCR result: [[('KA', 0.8498669862747192)]]
# True: NHÀ, Predicted (PaddleOCR):
# OCR result: [[('DUOC', 0.8107609152793884)]]
# True: THUỐC, Predicted (PaddleOCR):
# OCR result: [[('PHARMACY', 0.9973560571670532)]]
# True: PHARMACY, Predicted (PaddleOCR):
# OCR result: [[('iet', 0.9915551543235779)]]
# True: iệt, Predicted (PaddleOCR):
# OCR result: [[('Bao', 0.9948742985725403)]]
# True: Bảo, Predicted (PaddleOCR):
# OCR result: [[('Bao', 0.9945369362831116)]]
# True: Bảo, Predicted (PaddleOCR):
# OCR result: [[('Ve', 0.8002364635467529)]]
# True: vệ, Predicted (PaddleOCR):
# OCR result: [[('suc', 0.9489122033119202)]]
# True: sức, Predicted (PaddleOCR):
# OCR result: [[('khoe', 0.9946703910827637)]]
# True: khoẻ, Predicted (PaddleOCR):
# OCR result: [[('nguoi', 0.9764369130134583)]]
# True: người, Predicted (PaddleOCR):
# OCR result: [[('Viet', 0.9953815340995789)]]
# True: Việt, Predicted (PaddleOCR):
# OCR result: [[('DSPT:', 0.9741018414497375)]]
# True: DSPT:, Predicted (PaddleOCR):
# OCR result: [[('NGUYEN', 0.9968450665473938)]]
# True: NGUYỄN, Predicted (PaddleOCR):
# OCR result: [[('VAN', 0.9890022277832031)]]
# True: VĂN, Predicted (PaddleOCR):
# OCR result: [[('DUNG', 0.9970808625221252)]]
# True: DỤNG, Predicted (PaddleOCR):
# OCR result: [[('GPP.', 0.476826012134552)]]
# True: GPS:, Predicted (PaddleOCR):
# OCR result: [[('SC:', 0.7601561546325684)]]
# True: ĐC:, Predicted (PaddleOCR):
# OCR result: [[('30', 0.996259331703186)]]
# True: 30, Predicted (PaddleOCR):
# OCR result: [[('LUONG', 0.983833909034729)]]
# True: LƯƠNG, Predicted (PaddleOCR):
# OCR result: [[('YEN', 0.9841659665107727)]]
# True: YÊN, Predicted (PaddleOCR):
# OCR result: [[('8', 0.2260541170835495)]]
# True: -, Predicted (PaddleOCR):
# OCR result: [[('P', 0.9573285579681396)]]
# True: P., Predicted (PaddleOCR):
# OCR result: [[('BACH', 0.9982333183288574)]]
# True: BẠCH, Predicted (PaddleOCR):
# OCR result: [[('DANG', 0.9963961243629456)]]
# True: ĐẰNG, Predicted (PaddleOCR):
# OCR result: [[('-', 0.7038201093673706)]]
# True: -, Predicted (PaddleOCR):
# OCR result: [[('Q.', 0.9475498199462891)]]
# True: Q., Predicted (PaddleOCR):
# OCR result: [[('HAI', 0.9922080039978027)]]
# True: HAI, Predicted (PaddleOCR):
# OCR result: [[('BA', 0.9962437152862549)]]
# True: BÀ, Predicted (PaddleOCR):
# OCR result: [[('TRUNG', 0.9718698263168335)]]
# True: TRƯNG, Predicted (PaddleOCR):
# OCR result: [[('HA', 0.9942255020141602)]]
# True: HÀ, Predicted (PaddleOCR):
# OCR result: [[('NOI', 0.8337038159370422)]]
# True: NỘI, Predicted (PaddleOCR):
# OCR result: [[('DT:', 0.846616268157959)]]
# True: ĐT:, Predicted (PaddleOCR):
# OCR result: [[('0968 656003', 0.9435709118843079)]]
# True: 0968656003, Predicted (PaddleOCR):
# OCR result: [[('NHA', 0.9948641657829285)]]
# True: NHÀ, Predicted (PaddleOCR):
# OCR result: [[('THUOC', 0.9961487054824829)]]
# True: THUỐC, Predicted (PaddleOCR):
# OCR result: [[('VIET', 0.9943895936012268)]]
# True: VIỆT, Predicted (PaddleOCR):
# OCR result: [[('BAO', 0.9903530478477478)]]
# True: BẢO, Predicted (PaddleOCR):
# OCR result: [[('Tet', 0.9201719164848328)]]
# True: Tết, Predicted (PaddleOCR):
# OCR result: [[('sum', 0.9974022507667542)]]
# True: sum, Predicted (PaddleOCR):
# OCR result: [[('vay', 0.7691650986671448)]]
# True: vầy, Predicted (PaddleOCR):
# OCR result: [[('dong', 0.9990066289901733)]]
# True: đong, Predicted (PaddleOCR):
# OCR result: [[('day', 0.9769237637519836)]]
# True: đầy, Predicted (PaddleOCR):
# OCR result: [[('Dlem', 0.8896043300628662)]]
# True: Điểm, Predicted (PaddleOCR):
# OCR result: [[('thuong', 0.9916815757751465)]]
# True: thưởng, Predicted (PaddleOCR):
# OCR result: [[('chuong', 0.9729118943214417)]]
# True: Chương, Predicted (PaddleOCR):
# OCR result: [[('trinn', 0.9094995260238647)]]
# True: trình, Predicted (PaddleOCR):
# OCR result: [[('tich', 0.96442711353302)]]
# True: tích, Predicted (PaddleOCR):
# OCR result: [[('va', 0.6761417388916016)]]
# True: và, Predicted (PaddleOCR):
# OCR result: [[('tleu', 0.8767073154449463)]]
# True: tiêu, Predicted (PaddleOCR):
# OCR result: [[('DlEm', 0.7315017580986023)]]
# True: điểm, Predicted (PaddleOCR):
# OCR result: [[('thuong', 0.9922090172767639)]]
# True: thưởng, Predicted (PaddleOCR):
# OCR result: [[('tren', 0.9978373646736145)]]
# True: trên, Predicted (PaddleOCR):
# OCR result: [[('mol', 0.7630502581596375)]]
# True: mỗi, Predicted (PaddleOCR):
# OCR result: [[('hoa', 0.8977941870689392)]]
# True: hoá, Predicted (PaddleOCR):
# OCR result: [[('don', 0.9856101870536804)]]
# True: đơn, Predicted (PaddleOCR):
# OCR result: [[('mua', 0.8908340334892273)]]
# True: mua, Predicted (PaddleOCR):
# OCR result: [[('hang', 0.9758415818214417)]]
# True: hàng, Predicted (PaddleOCR):
# OCR result: [[('UOT', 0.9496345520019531)]]
# True: ƯỚT, Predicted (PaddleOCR):
# OCR result: [[('SAT', 0.8700419068336487)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('MHO', 0.8261756896972656)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('30', 0.9987290501594543)]]
# True: 30, Predicted (PaddleOCR):
# OCR result: [[('LUO', 0.9698206782341003)]]
# True: LƯƠ, Predicted (PaddleOCR):
# OCR result: [[('M', 0.37845340371131897)]]
# True: NHÀ, Predicted (PaddleOCR):
# OCR result: [[('B', 0.14154669642448425)]]
# True: THUỐC, Predicted (PaddleOCR):
# OCR result: [[('If', 0.39220577478408813)]]
# True: MỸ, Predicted (PaddleOCR):
# OCR result: [[('PHAy', 0.48769310116767883)]]
# True: PHẨM, Predicted (PaddleOCR):
# OCR result: [[('io', 0.33665502071380615)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('CAO', 0.9286112189292908)]]
# True: CAO, Predicted (PaddleOCR):
# OCR result: [[('SU', 0.8928966522216797)]]
# True: SU, Predicted (PaddleOCR):
# OCR result: [[('of', 0.4569462537765503)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('UPN', 0.6511427760124207)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('PRONG', 0.7245432138442993)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('BACE', 0.6267393827438354)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('BANE', 0.33283519744873047)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('C', 0.29415425658226013)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('9', 0.07741948217153549)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('PH', 0.578812301158905)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('M', 0.12985709309577942)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('$0', 0.32854926586151123)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('3', 0.5068383812904358)]]
# True: ###, Predicted (PaddleOCR):
# OCR result: [[('DOAN', 0.9959062337875366)]]
# True: ĐOẠN, Predicted (PaddleOCR):
# OCR result: [[('DUNG', 0.9262096881866455)]]
# True: ĐƯỜNG, Predicted (PaddleOCR):
# OCR result: [[('TU', 0.9178775548934937)]]
# True: TỰ, Predicted (PaddleOCR):
# OCR result: [[('QUAN', 0.9866186380386353)]]
# True: QUẢN, Predicted (PaddleOCR):
# OCR result: [[('2', 0.9958000779151917)]]
# True: 2, Predicted (PaddleOCR):
# OCR result: [[('KHONG', 0.9962419271469116)]]
# True: KHÔNG, Predicted (PaddleOCR):
# True: ###, Predicted (TesseractOCR):
# True: CHẤT, Predicted (TesseractOCR): CHAT
# True: LƯỢNG, Predicted (TesseractOCR):
# True: TỐT, Predicted (TesseractOCR):
# True: ĐỂ, Predicted (TesseractOCR):
# True: CÓ, Predicted (TesseractOCR):
# True: VIỆC, Predicted (TesseractOCR):
# True: LÀM, Predicted (TesseractOCR): iN,
# True: NĂNG, Predicted (TesseractOCR):
# True: SUẤT, Predicted (TesseractOCR): uit
# True: CAO, Predicted (TesseractOCR):
# True: ĐỂ, Predicted (TesseractOCR):
# True: TĂNG, Predicted (TesseractOCR): ving
# True: THU, Predicted (TesseractOCR):
# True: NHẬP, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CỔNG, Predicted (TesseractOCR): CONG
# True: TRƯỜNG, Predicted (TesseractOCR): TRUONG
# True: AN, Predicted (TesseractOCR):
# True: TOÀN, Predicted (TesseractOCR):
# True: GIAO, Predicted (TesseractOCR):
# True: THÔNG, Predicted (TesseractOCR):
# True: Dừng, Predicted (TesseractOCR):
# True: lại, Predicted (TesseractOCR):
# True: quan, Predicted (TesseractOCR):
# True: sát, Predicted (TesseractOCR): Sat
# True: trước, Predicted (TesseractOCR): truoc
# True: khi, Predicted (TesseractOCR):
# True: qua, Predicted (TesseractOCR): qua
# True: đường, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: Ngân, Predicted (TesseractOCR):
# True: hàn, Predicted (TesseractOCR):
# True: Vie, Predicted (TesseractOCR): Vie
# True: Ch, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: TRƯỜNG, Predicted (TesseractOCR):
# True: ĐANG, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): re
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: TRƯỜNG, Predicted (TesseractOCR):
# True: BÃI, Predicted (TesseractOCR): Bal
# True: GỬI, Predicted (TesseractOCR): cl
# True: XE, Predicted (TesseractOCR): KE
# True: HÃY, Predicted (TesseractOCR): HAY
# True: NGĂN, Predicted (TesseractOCR):
# True: CHẶN, Predicted (TesseractOCR):
# True: NẠN, Predicted (TesseractOCR):
# True: BUÔN, Predicted (TesseractOCR): BUON
# True: BÁN, Predicted (TesseractOCR):
# True: PHỤ, Predicted (TesseractOCR):
# True: NỮ, Predicted (TesseractOCR):
# True: VÀ, Predicted (TesseractOCR):
# True: TRẺ, Predicted (TesseractOCR):
# True: EM, Predicted (TesseractOCR):
# True: NHÀ, Predicted (TesseractOCR):
# True: THUỐC, Predicted (TesseractOCR):
# True: PHARMACY, Predicted (TesseractOCR): 2HARMAGY
# True: iệt, Predicted (TesseractOCR):
# True: Bảo, Predicted (TesseractOCR):
# True: Bảo, Predicted (TesseractOCR): Bao
# True: vệ, Predicted (TesseractOCR): ve
# True: sức, Predicted (TesseractOCR): SUC
# True: khoẻ, Predicted (TesseractOCR): khoe
# True: người, Predicted (TesseractOCR): nguoi
# True: Việt, Predicted (TesseractOCR): Viet
# True: DSPT:, Predicted (TesseractOCR):
# True: NGUYỄN, Predicted (TesseractOCR): NGUYEN
# True: VĂN, Predicted (TesseractOCR): VAN
# True: DỤNG, Predicted (TesseractOCR): DUNG
# True: GPS:, Predicted (TesseractOCR): GPS:
# True: ĐC:, Predicted (TesseractOCR):
# True: 30, Predicted (TesseractOCR):
# True: LƯƠNG, Predicted (TesseractOCR):
# True: YÊN, Predicted (TesseractOCR): vEN
# True: -, Predicted (TesseractOCR):
# True: P., Predicted (TesseractOCR):
# True: BẠCH, Predicted (TesseractOCR): BACH
# True: ĐẰNG, Predicted (TesseractOCR): DANG
# True: -, Predicted (TesseractOCR):
# True: Q., Predicted (TesseractOCR):
# True: HAI, Predicted (TesseractOCR): HAI
# True: BÀ, Predicted (TesseractOCR):
# True: TRƯNG, Predicted (TesseractOCR):
# True: HÀ, Predicted (TesseractOCR): HA
# True: NỘI, Predicted (TesseractOCR):
# True: ĐT:, Predicted (TesseractOCR):
# True: 0968656003, Predicted (TesseractOCR): 0968 656 003
# True: NHÀ, Predicted (TesseractOCR):
# True: THUỐC, Predicted (TesseractOCR): THUOC
# True: VIỆT, Predicted (TesseractOCR): VIET
# True: BẢO, Predicted (TesseractOCR): BAO
# True: Tết, Predicted (TesseractOCR): Tet
# True: sum, Predicted (TesseractOCR): sum
# True: vầy, Predicted (TesseractOCR): vay
# True: đong, Predicted (TesseractOCR): dong
# True: đầy, Predicted (TesseractOCR):
# True: Điểm, Predicted (TesseractOCR): pient
# True: thưởng, Predicted (TesseractOCR):
# True: Chương, Predicted (TesseractOCR):
# True: trình, Predicted (TesseractOCR): trinh
# True: tích, Predicted (TesseractOCR): tich
# True: và, Predicted (TesseractOCR): va
# True: tiêu, Predicted (TesseractOCR): tiéu
# True: điểm, Predicted (TesseractOCR): Diém
# True: thưởng, Predicted (TesseractOCR):
# True: trên, Predicted (TesseractOCR): trén
# True: mỗi, Predicted (TesseractOCR): moi
# True: hoá, Predicted (TesseractOCR):
# True: đơn, Predicted (TesseractOCR): dor
# True: mua, Predicted (TesseractOCR):
# True: hàng, Predicted (TesseractOCR):
# True: ƯỚT, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): BHO
# True: 30, Predicted (TesseractOCR): 30
# True: LƯƠ, Predicted (TesseractOCR): LUC
# True: NHÀ, Predicted (TesseractOCR): : an
# True: THUỐC, Predicted (TesseractOCR):
# True: MỸ, Predicted (TesseractOCR): |
# True: PHẨM, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): pe
# True: CAO, Predicted (TesseractOCR):
# True: SU, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ĐOẠN, Predicted (TesseractOCR):
# True: ĐƯỜNG, Predicted (TesseractOCR):
# True: TỰ, Predicted (TesseractOCR):
# True: QUẢN, Predicted (TesseractOCR):
# True: 2, Predicted (TesseractOCR):
# True: KHÔNG, Predicted (TesseractOCR): KHONG
# [[('HOF', 0.7248262763023376)]]
# [[('CHAT', 0.9970598220825195)]]
# [[('LUONG', 0.8340489268302917)]]
# [[('TOT', 0.6198198795318604)]]
# [[('DE', 0.9875959157943726)]]
# [[('CO', 0.7626323699951172)]]
# [[('VIEC', 0.827197253704071)]]
# [[('LAM,', 0.8659693598747253)]]
# [[('NANG', 0.9824891090393066)]]
# [[('SUAT', 0.9761183261871338)]]
# [[('CAO', 0.9812984466552734)]]
# [[('DE', 0.9742392301559448)]]
# [[('TANG', 0.9967201948165894)]]
# [[('THU', 0.9941852688789368)]]
# [[('NHAP', 0.8980079889297485)]]
# [[('am', 0.5149505138397217)]]
# [[('a0', 0.11906231194734573)]]
# [[('-', 0.35519713163375854)]]
# [[('', 0.0)]]
# [[('C', 0.12205097079277039)]]
# [[('i', 0.2419385313987732)]]
# [[('2', 0.15024158358573914)]]
# [[('O', 0.21958497166633606)]]
# [[('n', 0.2101198434829712)]]
# [[('TER', 0.28574568033218384)]]
# [[('LS', 0.3546040654182434)]]
# [[('O', 0.1922067105770111)]]
# [[('TIEr', 0.6346054077148438)]]
# [[('I', 0.2683390974998474)]]
# [[('S02E', 0.2676371932029724)]]
# [[('CONG', 0.996503472328186)]]
# [[('TRUONG', 0.9205740094184875)]]
# [[('AN', 0.9973358511924744)]]
# [[('TOAN', 0.9981263279914856)]]
# [[('GIAO', 0.9927723407745361)]]
# [[('THONG', 0.9980703592300415)]]
# [[('Dung', 0.9720937013626099)]]
# [[('lai', 0.9779927134513855)]]
# [[('quan', 0.9973017573356628)]]
# [[('sat', 0.9958863854408264)]]
# [[('truoc', 0.9935256838798523)]]
# [[('khi', 0.9907448291778564)]]
# [[('enb', 0.9869994521141052)]]
# [[('duong', 0.9985593557357788)]]
# [[('BAN', 0.9491246342658997)]]
# [[('Ngan', 0.7521347403526306)]]
# [[('han', 0.8118379712104797)]]
# [[('VIe', 0.8804585337638855)]]
# [[('Ch', 0.9899793863296509)]]
# [[('COND', 0.9215390086174011)]]
# [[('IRUONG', 0.7666494250297546)]]
# [[('SANG', 0.7818746566772461)]]
# [[('8', 0.07697561383247375)]]
# [[('LONG', 0.807560920715332)]]
# [[('CAM', 0.9569395184516907)]]
# [[('o', 0.12506254017353058)]]
# [[('T', 0.7708498239517212)]]
# [[('ROA', 0.3235209882259369)]]
# [[('ERAM', 0.6682843565940857)]]
# [[('U', 0.1302759349346161)]]
# [[('SHE', 0.4318881332874298)]]
# [[('RO', 0.4087999165058136)]]
# [[('TON', 0.9173479676246643)]]
# [[('OUAY', 0.7586358785629272)]]
# [[('CONO', 0.5619122982025146)]]
# [[('TEUONG', 0.6592857241630554)]]
# [[('BAI', 0.9373375773429871)]]
# [[('GU', 0.7155078649520874)]]
# [[('XE', 0.996226966381073)]]
# [[('HAY', 0.9933437705039978)]]
# [[('NGAN', 0.9974562525749207)]]
# [[('CHAN', 0.9962782859802246)]]
# [[('NAN', 0.9974414706230164)]]
# [[('BUON', 0.9970767498016357)]]
# [[('BAN', 0.9965600371360779)]]
# [[('PHU', 0.9259838461875916)]]
# [[('AN', 0.7066661715507507)]]
# [[('VA', 0.9889934062957764)]]
# [[('TRE', 0.9959554672241211)]]
# [[('EM', 0.9953380823135376)]]
# [[('KA', 0.8498669862747192)]]
# [[('DUOC', 0.8107609152793884)]]
# [[('PHARMACY', 0.9973560571670532)]]
# [[('iet', 0.9915551543235779)]]
# [[('Bao', 0.9948742985725403)]]
# [[('Bao', 0.9945369362831116)]]
# [[('Ve', 0.8002364635467529)]]
# [[('suc', 0.9489122033119202)]]
# [[('khoe', 0.9946703910827637)]]
# [[('nguoi', 0.9764369130134583)]]
# [[('Viet', 0.9953815340995789)]]
# [[('DSPT:', 0.9741018414497375)]]
# [[('NGUYEN', 0.9968450665473938)]]
# [[('VAN', 0.9890022277832031)]]
# [[('DUNG', 0.9970808625221252)]]
# [[('GPP.', 0.476826012134552)]]
# [[('SC:', 0.7601561546325684)]]
# [[('30', 0.996259331703186)]]
# [[('LUONG', 0.983833909034729)]]
# [[('YEN', 0.9841659665107727)]]
# [[('8', 0.2260541170835495)]]
# [[('P', 0.9573285579681396)]]
# [[('BACH', 0.9982333183288574)]]
# [[('DANG', 0.9963961243629456)]]
# [[('-', 0.7038201093673706)]]
# [[('Q.', 0.9475498199462891)]]
# [[('HAI', 0.9922080039978027)]]
# [[('BA', 0.9962437152862549)]]
# [[('TRUNG', 0.9718698263168335)]]
# [[('HA', 0.9942255020141602)]]
# [[('NOI', 0.8337038159370422)]]
# [[('DT:', 0.846616268157959)]]
# [[('0968 656003', 0.9435709118843079)]]
# [[('NHA', 0.9948641657829285)]]
# [[('THUOC', 0.9961487054824829)]]
# [[('VIET', 0.9943895936012268)]]
# [[('BAO', 0.9903530478477478)]]
# [[('Tet', 0.9201719164848328)]]
# [[('sum', 0.9974022507667542)]]
# [[('vay', 0.7691650986671448)]]
# [[('dong', 0.9990066289901733)]]
# [[('day', 0.9769237637519836)]]
# [[('Dlem', 0.8896043300628662)]]
# [[('thuong', 0.9916815757751465)]]
# [[('chuong', 0.9729118943214417)]]
# [[('trinn', 0.9094995260238647)]]
# [[('tich', 0.96442711353302)]]
# [[('va', 0.6761417388916016)]]
# [[('tleu', 0.8767073154449463)]]
# [[('DlEm', 0.7315017580986023)]]
# [[('thuong', 0.9922090172767639)]]
# [[('tren', 0.9978373646736145)]]
# [[('mol', 0.7630502581596375)]]
# [[('hoa', 0.8977941870689392)]]
# [[('don', 0.9856101870536804)]]
# [[('mua', 0.8908340334892273)]]
# [[('hang', 0.9758415818214417)]]
# [[('UOT', 0.9496345520019531)]]
# [[('SAT', 0.8700419068336487)]]
# [[('MHO', 0.8261756896972656)]]
# [[('30', 0.9987290501594543)]]
# [[('LUO', 0.9698206782341003)]]
# [[('M', 0.37845340371131897)]]
# [[('B', 0.14154669642448425)]]
# [[('If', 0.39220577478408813)]]
# [[('PHAy', 0.48769310116767883)]]
# [[('io', 0.33665502071380615)]]
# [[('CAO', 0.9286112189292908)]]
# [[('SU', 0.8928966522216797)]]
# [[('of', 0.4569462537765503)]]
# [[('UPN', 0.6511427760124207)]]
# [[('PRONG', 0.7245432138442993)]]
# [[('BACE', 0.6267393827438354)]]
# [[('BANE', 0.33283519744873047)]]
# [[('C', 0.29415425658226013)]]
# [[('9', 0.07741948217153549)]]
# [[('PH', 0.578812301158905)]]
# [[('M', 0.12985709309577942)]]
# [[('$0', 0.32854926586151123)]]
# [[('3', 0.5068383812904358)]]
# [[('DOAN', 0.9959062337875366)]]
# [[('DUNG', 0.9262096881866455)]]
# [[('TU', 0.9178775548934937)]]
# [[('QUAN', 0.9866186380386353)]]
# [[('2', 0.9958000779151917)]]
# [[('KHONG', 0.9962419271469116)]]
#    Framework  Avg Runtime (s)  Avg CER (%)  Avg WER (%)  \
# 0    easyocr         0.011742    61.892570    81.927711
# 1  paddleocr         0.036176   100.000000   100.000000
# 2  tesseract         0.082575    81.736948    98.192771
#
#    Exact Match Accuracy (%)
# 0                 19.277108
# 1                  0.000000
# 2                  3.614458
