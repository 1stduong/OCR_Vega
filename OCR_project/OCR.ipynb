# %%
import numpy as np #2.2.1
import cv2 #4.10.0.84
import os
from natsort import natsorted
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
#OCR Framework
import pytesseract
from paddleocr import PaddleOCR
import paddle
import easyocr

#OCR Metrics
from jiwer import wer, cer
import time

# %%
print("PaddlePaddle device:", paddle.device.get_device())
# Out:
# PaddlePaddle device: cpu

# %% [markdown]
# Pytesseract, PaddleOCR, EasyOCR
# Metrics used: CER(Character Error Rate), WER(Word Error Rate), EMA(Exact Match Accuracy)

# %%
def parse_label_files(label_folder, num_files):
    annotations = {}
    label_files = natsorted(os.listdir(label_folder))[:num_files]  # Take only the specified number of files
    for label_file in label_files:
        file_path = os.path.join(label_folder, label_file)
        with open(file_path, 'r') as file:
            annotation = []
            for line in file:
                data = line.strip().split(',')
                coords = list(map(int, data[:8]))  # First 8 values are bounding box coordinates
                text = data[8]  # The 9th value is the text
                annotation.append((coords, text))
        annotations[label_file] = annotation
    return annotations

def draw_boxes(image_folder, label_folder, num_files, font_path="/usr/share/fonts/truetype/noto/NotoSans-Regular.ttf", font_size = 16):
    annotations = parse_label_files(label_folder, num_files)
    label_files = sorted(annotations.keys())  # Ensure labels are sorted in the right order

    for i, label_file in enumerate(label_files):
        # Generate the corresponding image name starting from "im0001.jpg"
        image_file = f"im{i + 1:04d}.jpg"  # Format index with leading zeros (e.g., im0001.jpg)
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        # Read and draw bounding boxes on the image
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Convert to a Pillow Image
        pil_image = Image.fromarray(image)
        draw = ImageDraw.Draw(pil_image)

        # Load the Noto Sans font
        font = ImageFont.truetype(font_path, font_size)

        # Draw bounding boxes and text
        for coords, text in annotations[label_file]:
            pts = [(coords[i], coords[i + 1]) for i in range(0, len(coords), 2)]
            draw.polygon(pts, outline="green", width=2)
            draw.text((pts[0][0], pts[0][1] - font_size), text, fill="green", font=font)

        # Convert back to OpenCV format
        image = np.array(pil_image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Display the image
        cv2.imshow(f"Image: {image_file}", image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
def crop_text_regions(image, coords):
    """Crop text regions using bounding box coordinates."""
    pts = np.array(coords, dtype=np.int32).reshape((4, 2))
    rect = cv2.boundingRect(pts)
    x, y, w, h = rect
    cropped = image[y:y+h, x:x+w]
    return cropped

# %%
def apply_easyocr(image_folder, label_folder, num_files):
    reader = easyocr.Reader(['en', 'vi'])  # Adjust languages as needed
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)
            result = reader.readtext(cropped)
            predicted_text = result[0][-2] if result else ""
            print(f"True: {true_text}, Predicted (EasyOCR): {predicted_text}")

# %%
def apply_paddleocr(image_folder, label_folder, num_files):
    ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Adjust language if needed
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)
            
            # Process the cropped image directly without saving
            result = ocr.ocr(cropped, det=False)
            if result and result[0]:  # Check for valid result
                predicted_text = result[0][1][0]  # Extract the text
            else:
                predicted_text = ""
            
            print(f"True: {true_text}, Predicted (PaddleOCR): {predicted_text}")

# %%
def apply_tesseractocr(image_folder, label_folder, num_files):
    annotations = parse_label_files(label_folder, num_files)
    label_files = natsorted(annotations.keys())  # Ensure label files are sorted correctly

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        # Generate the correct image name (im0001.jpg, im0002.jpg, ...)
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found for {label_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)
            predicted_text = pytesseract.image_to_string(cropped, lang='eng')
            print(f"True: {true_text}, Predicted (TesseractOCR): {predicted_text.strip()}")

# %%
# Calculate runtime and metrics
easyocr_reader = easyocr.Reader(["en", "vi"])  # EasyOCR
paddle_ocr = PaddleOCR(use_angle_cls=True, lang="en")  # PaddleOCR

def calculate_metrics(ocr_framework, image_folder, label_folder, num_files):
    annotations = parse_label_files(label_folder, num_files)
    runtimes = []
    cer_list = []
    wer_list = []
    exact_matches = 0

    for idx, (label_file, annotation) in enumerate(annotations.items()):
        image_file = f"im{idx + 1:04d}.jpg"
        image_path = os.path.join(image_folder, image_file)

        if not os.path.exists(image_path):
            print(f"Image file not found: {image_file}")
            continue

        image = cv2.imread(image_path)
        for coords, true_text in annotation:
            cropped = crop_text_regions(image, coords)

            # Measure runtime
            start_time = time.time()
            if ocr_framework == "easyocr":
                result = easyocr_reader.readtext(cropped)
                predicted_text = result[0][-2] if result else ""
            elif ocr_framework == "paddleocr":
                # Process the cropped image directly without saving
                result = paddle_ocr.ocr(cropped, det=False)
                print(result)  # Debugging: Print the result structure
                try:
                    if result and isinstance(result[0], list) and result[0]:
                        predicted_text = result[0][0][1][0]  # Extract text
                    else:
                        predicted_text = ""
                except (IndexError, TypeError):
                    predicted_text = ""
            elif ocr_framework == "tesseract":
                predicted_text = pytesseract.image_to_string(cropped, lang="eng").strip()
            else:
                raise ValueError("Invalid OCR framework")
            end_time = time.time()

            # Update metrics
            runtimes.append(end_time - start_time)
            cer_list.append(cer(true_text, predicted_text))
            wer_list.append(wer(true_text, predicted_text))
            if true_text == predicted_text:
                exact_matches += 1

    # Aggregate results
    avg_runtime = np.mean(runtimes)
    avg_cer = np.mean(cer_list) * 100  # Convert to percentage
    avg_wer = np.mean(wer_list) * 100  # Convert to percentage
    exact_match_accuracy = (exact_matches / sum(len(ann) for ann in annotations.values())) * 100

    return {
        "Framework": ocr_framework,
        "Avg Runtime (s)": avg_runtime,
        "Avg CER (%)": avg_cer,
        "Avg WER (%)": avg_wer,
        "Exact Match Accuracy (%)": exact_match_accuracy,
    }
# Out:
# [2024/12/24 10:29:34] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/nhduong141103/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/nhduong141103/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/nhduong141103/VegaCop/OCR/OCR/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/nhduong141103/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')

# %%
image_folder = "/home/nhduong141103/VegaCop/OCR/OCR_project/ocr-dataset-20241224/images/"
label_folder = "/home/nhduong141103/VegaCop/OCR/OCR_project/ocr-dataset-20241224/labels/"
font_path = "/usr/share/fonts/truetype/noto/NotoSans-Regular.ttf"

#draw_boxes(image_folder, label_folder, 5, font_path = font_path, font_size = 20)

# Number of files to process
num_files = 5

# Apply EasyOCR
apply_easyocr(image_folder, label_folder, num_files) #Working

# Apply PaddleOCR
apply_paddleocr(image_folder, label_folder, num_files) #Setup Error

# Apply TesseractOCR
apply_tesseractocr(image_folder, label_folder, num_files) #Working

# Calculate metrics
results_easyocr = calculate_metrics("easyocr", image_folder, label_folder, num_files)
results_paddleocr = calculate_metrics("paddleocr", image_folder, label_folder, num_files)
results_tesseract = calculate_metrics("tesseract", image_folder, label_folder, num_files)

results_df = pd.DataFrame([results_easyocr, results_paddleocr, results_tesseract])
print(results_df)
# Out:
# True: ###, Predicted (EasyOCR):
# True: CHẤT, Predicted (EasyOCR): OH
# True: LƯỢNG, Predicted (EasyOCR): WUI
# True: TỐT, Predicted (EasyOCR):
# True: ĐỂ, Predicted (EasyOCR):
# True: CÓ, Predicted (EasyOCR):
# True: VIỆC, Predicted (EasyOCR): VEC
# True: LÀM, Predicted (EasyOCR):
# True: NĂNG, Predicted (EasyOCR): HiN
# True: SUẤT, Predicted (EasyOCR): SV]
# True: CAO, Predicted (EasyOCR): 6
# True: ĐỂ, Predicted (EasyOCR):
# True: TĂNG, Predicted (EasyOCR): TINA
# True: THU, Predicted (EasyOCR):
# True: NHẬP, Predicted (EasyOCR): HKAP
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CỔNG, Predicted (EasyOCR): CỔNG
# True: TRƯỜNG, Predicted (EasyOCR): TRUÒNG
# True: AN, Predicted (EasyOCR): AN
# True: TOÀN, Predicted (EasyOCR): TOÀN
# True: GIAO, Predicted (EasyOCR): GIAO
# True: THÔNG, Predicted (EasyOCR): THONG
# True: Dừng, Predicted (EasyOCR): Dùng
# True: lại, Predicted (EasyOCR): lai
# True: quan, Predicted (EasyOCR): quan
# True: sát, Predicted (EasyOCR): sát
# True: trước, Predicted (EasyOCR): trưóc
# True: khi, Predicted (EasyOCR): khi
# True: qua, Predicted (EasyOCR): qua
# True: đường, Predicted (EasyOCR): đuòng
# True: ###, Predicted (EasyOCR):
# True: Ngân, Predicted (EasyOCR):
# True: hàn, Predicted (EasyOCR):
# True: Vie, Predicted (EasyOCR): Vie
# True: Ch, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: TRƯỜNG, Predicted (EasyOCR):
# True: ĐANG, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: CÔNG, Predicted (EasyOCR):
# True: TRƯỜNG, Predicted (EasyOCR):
# True: BÃI, Predicted (EasyOCR): BÃl
# True: GỬI, Predicted (EasyOCR): GU
# True: XE, Predicted (EasyOCR): XE
# True: HÃY, Predicted (EasyOCR): HÃY
# True: NGĂN, Predicted (EasyOCR): NGĂN
# True: CHẶN, Predicted (EasyOCR): CHẶN
# True: NẠN, Predicted (EasyOCR): NAN
# True: BUÔN, Predicted (EasyOCR): BUÔN
# True: BÁN, Predicted (EasyOCR): BÁN
# True: PHỤ, Predicted (EasyOCR): PHỤ
# True: NỮ, Predicted (EasyOCR): NỮ
# True: VÀ, Predicted (EasyOCR): VÀ
# True: TRẺ, Predicted (EasyOCR): TRẺ
# True: EM, Predicted (EasyOCR): EM
# True: NHÀ, Predicted (EasyOCR): K
# True: THUỐC, Predicted (EasyOCR): 2É
# True: PHARMACY, Predicted (EasyOCR): Picl
# True: iệt, Predicted (EasyOCR): iêt
# True: Bảo, Predicted (EasyOCR): Bảo
# True: Bảo, Predicted (EasyOCR): Bảo
# True: vệ, Predicted (EasyOCR): Vệ
# True: sức, Predicted (EasyOCR): Súc
# True: khoẻ, Predicted (EasyOCR): khoẻ
# True: người, Predicted (EasyOCR): nguời
# True: Việt, Predicted (EasyOCR): Việt
# True: DSPT:, Predicted (EasyOCR): DSPT:
# True: NGUYỄN, Predicted (EasyOCR): NGUYÊN
# True: VĂN, Predicted (EasyOCR): VĂI]
# True: DỤNG, Predicted (EasyOCR): DUIG
# True: GPS:, Predicted (EasyOCR): GFS:
# True: ĐC:, Predicted (EasyOCR): DC:
# True: 30, Predicted (EasyOCR): 30
# True: LƯƠNG, Predicted (EasyOCR): LUONG
# True: YÊN, Predicted (EasyOCR): VÊN
# True: -, Predicted (EasyOCR):
# True: P., Predicted (EasyOCR): P
# True: BẠCH, Predicted (EasyOCR): BACH
# True: ĐẰNG, Predicted (EasyOCR): DĂNIG
# True: -, Predicted (EasyOCR):
# True: Q., Predicted (EasyOCR): 0
# True: HAI, Predicted (EasyOCR): HAI
# True: BÀ, Predicted (EasyOCR): BA
# True: TRƯNG, Predicted (EasyOCR): TRUIG
# True: HÀ, Predicted (EasyOCR): HA
# True: NỘI, Predicted (EasyOCR): Noi
# True: ĐT:, Predicted (EasyOCR): DT:
# True: 0968656003, Predicted (EasyOCR): 0968 656 003
# True: NHÀ, Predicted (EasyOCR): NHÀ
# True: THUỐC, Predicted (EasyOCR): ThUỐc
# True: VIỆT, Predicted (EasyOCR): VIÊT
# True: BẢO, Predicted (EasyOCR): BẢO
# True: Tết, Predicted (EasyOCR): Tet
# True: sum, Predicted (EasyOCR): SUm
# True: vầy, Predicted (EasyOCR): vày
# True: đong, Predicted (EasyOCR): dong
# True: đầy, Predicted (EasyOCR): Gay
# True: Điểm, Predicted (EasyOCR): Dlem
# True: thưởng, Predicted (EasyOCR): churong
# True: Chương, Predicted (EasyOCR): Chuong
# True: trình, Predicted (EasyOCR): trinn
# True: tích, Predicted (EasyOCR): Uen
# True: và, Predicted (EasyOCR):
# True: tiêu, Predicted (EasyOCR): Lcu
# True: điểm, Predicted (EasyOCR): Dlem
# True: thưởng, Predicted (EasyOCR): thuong
# True: trên, Predicted (EasyOCR): tren
# True: mỗi, Predicted (EasyOCR): mo1
# True: hoá, Predicted (EasyOCR): n62
# True: đơn, Predicted (EasyOCR): dan
# True: mua, Predicted (EasyOCR): Ca
# True: hàng, Predicted (EasyOCR): hàng
# True: ƯỚT, Predicted (EasyOCR): UO7
# True: ###, Predicted (EasyOCR): SAT
# True: ###, Predicted (EasyOCR): GHô
# True: 30, Predicted (EasyOCR): 30
# True: LƯƠ, Predicted (EasyOCR): LƯO
# True: NHÀ, Predicted (EasyOCR):
# True: THUỐC, Predicted (EasyOCR):
# True: MỸ, Predicted (EasyOCR):
# True: PHẨM, Predicted (EasyOCR): V
# True: ###, Predicted (EasyOCR):
# True: CAO, Predicted (EasyOCR): G
# True: SU, Predicted (EasyOCR): 4
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ###, Predicted (EasyOCR):
# True: ĐOẠN, Predicted (EasyOCR): OOAN
# True: ĐƯỜNG, Predicted (EasyOCR): OuOhG
# True: TỰ, Predicted (EasyOCR): TU
# True: QUẢN, Predicted (EasyOCR): QUAh
# True: 2, Predicted (EasyOCR): 2
# True: KHÔNG, Predicted (EasyOCR): HhoNG
# [2024/12/24 10:51:35] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/nhduong141103/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/nhduong141103/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/nhduong141103/VegaCop/OCR/OCR/lib/python3.12/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/nhduong141103/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# True: ###, Predicted (PaddleOCR): ('HOF', 0.838488757610321)
# True: CHẤT, Predicted (PaddleOCR): ('CHAT', 0.9966933131217957)
# True: LƯỢNG, Predicted (PaddleOCR): ('LUONG', 0.7583346366882324)
# True: TỐT, Predicted (PaddleOCR): ('Ti', 0.4364413321018219)
# True: ĐỂ, Predicted (PaddleOCR): ('DE', 0.9911088943481445)
# True: CÓ, Predicted (PaddleOCR): ('CO', 0.8103803396224976)
# True: VIỆC, Predicted (PaddleOCR): ('VIEC', 0.795470118522644)
# True: LÀM, Predicted (PaddleOCR): ('LAM,', 0.9315711855888367)
# True: NĂNG, Predicted (PaddleOCR): ('NANG', 0.9232258796691895)
# True: SUẤT, Predicted (PaddleOCR): ('SUAT', 0.9528909921646118)
# True: CAO, Predicted (PaddleOCR): ('CAO', 0.9881640076637268)
# True: ĐỂ, Predicted (PaddleOCR): ('DE', 0.9106793403625488)
# True: TĂNG, Predicted (PaddleOCR): ('TANG', 0.9943826794624329)
# True: THU, Predicted (PaddleOCR): ('THU', 0.9874759316444397)
# True: NHẬP, Predicted (PaddleOCR): ('NHAP', 0.8982211351394653)
# True: ###, Predicted (PaddleOCR): ('am', 0.45274248719215393)
# True: ###, Predicted (PaddleOCR): ('a', 0.08395832031965256)
# True: ###, Predicted (PaddleOCR): ('-', 0.42702555656433105)
# True: ###, Predicted (PaddleOCR): ('-', 0.39139577746391296)
# True: ###, Predicted (PaddleOCR): ('-', 0.39158180356025696)
# True: ###, Predicted (PaddleOCR): ('i', 0.3098796010017395)
# True: ###, Predicted (PaddleOCR): ('2', 0.12732245028018951)
# True: ###, Predicted (PaddleOCR): ('a', 0.2324226349592209)
# True: ###, Predicted (PaddleOCR): ('R', 0.2732454538345337)
# True: ###, Predicted (PaddleOCR): ('E', 0.2811574637889862)
# True: ###, Predicted (PaddleOCR): ('LE', 0.46773743629455566)
# True: ###, Predicted (PaddleOCR): ('O', 0.1279284507036209)
# True: ###, Predicted (PaddleOCR): ('CIEr', 0.43970730900764465)
# True: ###, Predicted (PaddleOCR): ('I', 0.12506745755672455)
# True: ###, Predicted (PaddleOCR): ('SSEE', 0.35921287536621094)
# True: CỔNG, Predicted (PaddleOCR): ('CONG', 0.9965876936912537)
# True: TRƯỜNG, Predicted (PaddleOCR): ('TRUONG', 0.9224962592124939)
# True: AN, Predicted (PaddleOCR): ('AN', 0.9974963068962097)
# True: TOÀN, Predicted (PaddleOCR): ('TOAN', 0.9982101917266846)
# True: GIAO, Predicted (PaddleOCR): ('GIAO', 0.9925268292427063)
# True: THÔNG, Predicted (PaddleOCR): ('THONG', 0.9980387687683105)
# True: Dừng, Predicted (PaddleOCR): ('Dung', 0.9844697713851929)
# True: lại, Predicted (PaddleOCR): ('lai', 0.9825563430786133)
# True: quan, Predicted (PaddleOCR): ('quan', 0.9971192479133606)
# True: sát, Predicted (PaddleOCR): ('sat', 0.9961816668510437)
# True: trước, Predicted (PaddleOCR): ('truoc', 0.9925376772880554)
# True: khi, Predicted (PaddleOCR): ('khi', 0.9909138679504395)
# True: qua, Predicted (PaddleOCR): ('enb', 0.9860475659370422)
# True: đường, Predicted (PaddleOCR): ('duong', 0.9984904527664185)
# True: ###, Predicted (PaddleOCR): ('BAN', 0.9630748629570007)
# True: Ngân, Predicted (PaddleOCR): ('Ngan', 0.7583634853363037)
# True: hàn, Predicted (PaddleOCR): ('han', 0.8015078902244568)
# True: Vie, Predicted (PaddleOCR): ('VIe', 0.8769526481628418)
# True: Ch, Predicted (PaddleOCR): ('Ch', 0.9896555542945862)
# True: CÔNG, Predicted (PaddleOCR): ('LOND', 0.8151801824569702)
# True: TRƯỜNG, Predicted (PaddleOCR): ('IRUONG', 0.7479932308197021)
# True: ĐANG, Predicted (PaddleOCR): ('LANG', 0.7829468846321106)
# True: ###, Predicted (PaddleOCR): ('-', 0.10052555054426193)
# True: CÔNG, Predicted (PaddleOCR): ('LONG', 0.9301952719688416)
# True: ###, Predicted (PaddleOCR): ('CAM', 0.8009805083274841)
# True: ###, Predicted (PaddleOCR): ('od', 0.47362369298934937)
# True: ###, Predicted (PaddleOCR): ('T', 0.6993237733840942)
# True: ###, Predicted (PaddleOCR): ('PAA', 0.26044976711273193)
# True: ###, Predicted (PaddleOCR): ('EAM', 0.6309148669242859)
# True: ###, Predicted (PaddleOCR): ('SE', 0.16892465949058533)
# True: ###, Predicted (PaddleOCR): ('SHE', 0.4075244963169098)
# True: ###, Predicted (PaddleOCR): ('RAO', 0.37269046902656555)
# True: ###, Predicted (PaddleOCR): ('TON', 0.8705129027366638)
# True: ###, Predicted (PaddleOCR): ('OUAY', 0.6253834962844849)
# True: CÔNG, Predicted (PaddleOCR): ('CONO', 0.5655475854873657)
# True: TRƯỜNG, Predicted (PaddleOCR): ('EUONG', 0.6714362502098083)
# True: BÃI, Predicted (PaddleOCR): ('BAI', 0.9375337958335876)
# True: GỬI, Predicted (PaddleOCR): ('GU', 0.7482243776321411)
# True: XE, Predicted (PaddleOCR): ('XE', 0.9962923526763916)
# True: HÃY, Predicted (PaddleOCR): ('HAY', 0.9935972094535828)
# True: NGĂN, Predicted (PaddleOCR): ('NGAN', 0.9974300861358643)
# True: CHẶN, Predicted (PaddleOCR): ('CHAN', 0.9962278008460999)
# True: NẠN, Predicted (PaddleOCR): ('NAN', 0.9974009394645691)
# True: BUÔN, Predicted (PaddleOCR): ('BUON', 0.996929407119751)
# True: BÁN, Predicted (PaddleOCR): ('BAN', 0.9965388178825378)
# True: PHỤ, Predicted (PaddleOCR): ('PHU', 0.8553917407989502)
# True: NỮ, Predicted (PaddleOCR): ('AN', 0.706476092338562)
# True: VÀ, Predicted (PaddleOCR): ('VA', 0.9904916286468506)
# True: TRẺ, Predicted (PaddleOCR): ('TRE', 0.9957110285758972)
# True: EM, Predicted (PaddleOCR): ('EM', 0.9952834844589233)
# True: NHÀ, Predicted (PaddleOCR): ('KUA', 0.6444456577301025)
# True: THUỐC, Predicted (PaddleOCR): ('DUOC', 0.8162418603897095)
# True: PHARMACY, Predicted (PaddleOCR): ('PHARMACY', 0.9973467588424683)
# True: iệt, Predicted (PaddleOCR): ('iet', 0.9920948147773743)
# True: Bảo, Predicted (PaddleOCR): ('Bao', 0.9949899315834045)
# True: Bảo, Predicted (PaddleOCR): ('Bao', 0.9945221543312073)
# True: vệ, Predicted (PaddleOCR): ('Ve', 0.7821959257125854)
# True: sức, Predicted (PaddleOCR): ('suc', 0.9481810927391052)
# True: khoẻ, Predicted (PaddleOCR): ('khoe', 0.9942789673805237)
# True: người, Predicted (PaddleOCR): ('nguoi', 0.9783248901367188)
# True: Việt, Predicted (PaddleOCR): ('Viet', 0.9953482151031494)
# True: DSPT:, Predicted (PaddleOCR): ('DSPT:', 0.973922848701477)
# True: NGUYỄN, Predicted (PaddleOCR): ('NGUYEN', 0.9969484210014343)
# True: VĂN, Predicted (PaddleOCR): ('VAN', 0.9887208938598633)
# True: DỤNG, Predicted (PaddleOCR): ('DUNG', 0.9970712661743164)
# True: GPS:, Predicted (PaddleOCR): ('GPP.', 0.503823459148407)
# True: ĐC:, Predicted (PaddleOCR): ('SC:', 0.7837808132171631)
# True: 30, Predicted (PaddleOCR): ('30', 0.9963847398757935)
# True: LƯƠNG, Predicted (PaddleOCR): ('LUONG', 0.9803786277770996)
# True: YÊN, Predicted (PaddleOCR): ('YEN', 0.984623908996582)
# True: -, Predicted (PaddleOCR): ('8', 0.36395150423049927)
# True: P., Predicted (PaddleOCR): ('P', 0.9585705399513245)
# True: BẠCH, Predicted (PaddleOCR): ('BACH', 0.9982425570487976)
# True: ĐẰNG, Predicted (PaddleOCR): ('DANG', 0.9963417053222656)
# True: -, Predicted (PaddleOCR): ('-', 0.6684291362762451)
# True: Q., Predicted (PaddleOCR): ('Q.', 0.9616798758506775)
# True: HAI, Predicted (PaddleOCR): ('HAI', 0.9927288889884949)
# True: BÀ, Predicted (PaddleOCR): ('BA', 0.9961114525794983)
# True: TRƯNG, Predicted (PaddleOCR): ('TRUNG', 0.9758798480033875)
# True: HÀ, Predicted (PaddleOCR): ('HA', 0.9938449859619141)
# True: NỘI, Predicted (PaddleOCR): ('NOI', 0.822396457195282)
# True: ĐT:, Predicted (PaddleOCR): ('DT:', 0.8319124579429626)
# True: 0968656003, Predicted (PaddleOCR): ('0968 656003', 0.9418534636497498)
# True: NHÀ, Predicted (PaddleOCR): ('NHA', 0.9948484897613525)
# True: THUỐC, Predicted (PaddleOCR): ('THUOC', 0.9959867596626282)
# True: VIỆT, Predicted (PaddleOCR): ('VIET', 0.9943557977676392)
# True: BẢO, Predicted (PaddleOCR): ('BAO', 0.9902032017707825)
# True: Tết, Predicted (PaddleOCR): ('Tet', 0.9144197106361389)
# True: sum, Predicted (PaddleOCR): ('sum', 0.9974965453147888)
# True: vầy, Predicted (PaddleOCR): ('vay', 0.7812336087226868)
# True: đong, Predicted (PaddleOCR): ('dong', 0.9989920854568481)
# True: đầy, Predicted (PaddleOCR): ('day', 0.977658748626709)
# True: Điểm, Predicted (PaddleOCR): ('Dlem', 0.9029543399810791)
# True: thưởng, Predicted (PaddleOCR): ('thuong', 0.9926319718360901)
# True: Chương, Predicted (PaddleOCR): ('chuong', 0.9733586311340332)
# True: trình, Predicted (PaddleOCR): ('trinn', 0.9127860069274902)
# True: tích, Predicted (PaddleOCR): ('tich', 0.959099531173706)
# True: và, Predicted (PaddleOCR): ('va', 0.6539928913116455)
# True: tiêu, Predicted (PaddleOCR): ('tleu', 0.8457046151161194)
# True: điểm, Predicted (PaddleOCR): ('DlEm', 0.7345961332321167)
# True: thưởng, Predicted (PaddleOCR): ('thuong', 0.9902140498161316)
# True: trên, Predicted (PaddleOCR): ('tren', 0.9977816343307495)
# True: mỗi, Predicted (PaddleOCR): ('mol', 0.7616115212440491)
# True: hoá, Predicted (PaddleOCR): ('hoa', 0.908161461353302)
# True: đơn, Predicted (PaddleOCR): ('don', 0.9894356727600098)
# True: mua, Predicted (PaddleOCR): ('mua', 0.8923308849334717)
# True: hàng, Predicted (PaddleOCR): ('hang', 0.9828565120697021)
# True: ƯỚT, Predicted (PaddleOCR): ('UOT', 0.9561062455177307)
# True: ###, Predicted (PaddleOCR): ('SAT', 0.8514671921730042)
# True: ###, Predicted (PaddleOCR): ('MHO', 0.8144024014472961)
# True: 30, Predicted (PaddleOCR): ('30', 0.9986815452575684)
# True: LƯƠ, Predicted (PaddleOCR): ('LUO', 0.9712188243865967)
# True: NHÀ, Predicted (PaddleOCR): ('M', 0.3885140120983124)
# True: THUỐC, Predicted (PaddleOCR): ('', 0.0)
# True: MỸ, Predicted (PaddleOCR): ('If', 0.4479871392250061)
# True: PHẨM, Predicted (PaddleOCR): ('PHIy', 0.462397038936615)
# True: ###, Predicted (PaddleOCR): ('io', 0.43813854455947876)
# True: CAO, Predicted (PaddleOCR): ('CAO', 0.930533230304718)
# True: SU, Predicted (PaddleOCR): ('SU', 0.8628164529800415)
# True: ###, Predicted (PaddleOCR): ('ef', 0.45392948389053345)
# True: ###, Predicted (PaddleOCR): ('UPN', 0.770266056060791)
# True: ###, Predicted (PaddleOCR): ('PHONG', 0.6825853586196899)
# True: ###, Predicted (PaddleOCR): ('BACH', 0.6844664216041565)
# True: ###, Predicted (PaddleOCR): ('BANE', 0.3790944218635559)
# True: ###, Predicted (PaddleOCR): ('C8', 0.3778139650821686)
# True: ###, Predicted (PaddleOCR): ('o', 0.10912246257066727)
# True: ###, Predicted (PaddleOCR): ('PH', 0.5412973761558533)
# True: ###, Predicted (PaddleOCR): ('W', 0.11640109866857529)
# True: ###, Predicted (PaddleOCR): ('$o', 0.41148650646209717)
# True: ###, Predicted (PaddleOCR): ('3', 0.5087726712226868)
# True: ĐOẠN, Predicted (PaddleOCR): ('DOAN', 0.9959473013877869)
# True: ĐƯỜNG, Predicted (PaddleOCR): ('DUONG', 0.8649983406066895)
# True: TỰ, Predicted (PaddleOCR): ('TU', 0.9150327444076538)
# True: QUẢN, Predicted (PaddleOCR): ('QUAN', 0.987428605556488)
# True: 2, Predicted (PaddleOCR): ('2', 0.9955601692199707)
# True: KHÔNG, Predicted (PaddleOCR): ('KHONG', 0.9956094622612)
# True: ###, Predicted (TesseractOCR):
# True: CHẤT, Predicted (TesseractOCR): CHAT
# True: LƯỢNG, Predicted (TesseractOCR):
# True: TỐT, Predicted (TesseractOCR):
# True: ĐỂ, Predicted (TesseractOCR):
# True: CÓ, Predicted (TesseractOCR):
# True: VIỆC, Predicted (TesseractOCR):
# True: LÀM, Predicted (TesseractOCR): iN,
# True: NĂNG, Predicted (TesseractOCR):
# True: SUẤT, Predicted (TesseractOCR): uit
# True: CAO, Predicted (TesseractOCR):
# True: ĐỂ, Predicted (TesseractOCR):
# True: TĂNG, Predicted (TesseractOCR): ving
# True: THU, Predicted (TesseractOCR):
# True: NHẬP, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CỔNG, Predicted (TesseractOCR): CONG
# True: TRƯỜNG, Predicted (TesseractOCR): TRUONG
# True: AN, Predicted (TesseractOCR):
# True: TOÀN, Predicted (TesseractOCR):
# True: GIAO, Predicted (TesseractOCR):
# True: THÔNG, Predicted (TesseractOCR):
# True: Dừng, Predicted (TesseractOCR):
# True: lại, Predicted (TesseractOCR):
# True: quan, Predicted (TesseractOCR):
# True: sát, Predicted (TesseractOCR): Sat
# True: trước, Predicted (TesseractOCR): truoc
# True: khi, Predicted (TesseractOCR):
# True: qua, Predicted (TesseractOCR): qua
# True: đường, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: Ngân, Predicted (TesseractOCR):
# True: hàn, Predicted (TesseractOCR):
# True: Vie, Predicted (TesseractOCR): Vie
# True: Ch, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: TRƯỜNG, Predicted (TesseractOCR):
# True: ĐANG, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): re
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: CÔNG, Predicted (TesseractOCR):
# True: TRƯỜNG, Predicted (TesseractOCR):
# True: BÃI, Predicted (TesseractOCR): Bal
# True: GỬI, Predicted (TesseractOCR): cl
# True: XE, Predicted (TesseractOCR): KE
# True: HÃY, Predicted (TesseractOCR): HAY
# True: NGĂN, Predicted (TesseractOCR):
# True: CHẶN, Predicted (TesseractOCR):
# True: NẠN, Predicted (TesseractOCR):
# True: BUÔN, Predicted (TesseractOCR): BUON
# True: BÁN, Predicted (TesseractOCR):
# True: PHỤ, Predicted (TesseractOCR):
# True: NỮ, Predicted (TesseractOCR):
# True: VÀ, Predicted (TesseractOCR):
# True: TRẺ, Predicted (TesseractOCR):
# True: EM, Predicted (TesseractOCR):
# True: NHÀ, Predicted (TesseractOCR):
# True: THUỐC, Predicted (TesseractOCR):
# True: PHARMACY, Predicted (TesseractOCR): 2HARMAGY
# True: iệt, Predicted (TesseractOCR):
# True: Bảo, Predicted (TesseractOCR):
# True: Bảo, Predicted (TesseractOCR): Bao
# True: vệ, Predicted (TesseractOCR): ve
# True: sức, Predicted (TesseractOCR): SUC
# True: khoẻ, Predicted (TesseractOCR): khoe
# True: người, Predicted (TesseractOCR): nguoi
# True: Việt, Predicted (TesseractOCR): Viet
# True: DSPT:, Predicted (TesseractOCR):
# True: NGUYỄN, Predicted (TesseractOCR): NGUYEN
# True: VĂN, Predicted (TesseractOCR): VAN
# True: DỤNG, Predicted (TesseractOCR): DUNG
# True: GPS:, Predicted (TesseractOCR): GPS:
# True: ĐC:, Predicted (TesseractOCR):
# True: 30, Predicted (TesseractOCR):
# True: LƯƠNG, Predicted (TesseractOCR):
# True: YÊN, Predicted (TesseractOCR): vEN
# True: -, Predicted (TesseractOCR):
# True: P., Predicted (TesseractOCR):
# True: BẠCH, Predicted (TesseractOCR): BACH
# True: ĐẰNG, Predicted (TesseractOCR): DANG
# True: -, Predicted (TesseractOCR):
# True: Q., Predicted (TesseractOCR):
# True: HAI, Predicted (TesseractOCR): HAI
# True: BÀ, Predicted (TesseractOCR):
# True: TRƯNG, Predicted (TesseractOCR):
# True: HÀ, Predicted (TesseractOCR): HA
# True: NỘI, Predicted (TesseractOCR):
# True: ĐT:, Predicted (TesseractOCR):
# True: 0968656003, Predicted (TesseractOCR): 0968 656 003
# True: NHÀ, Predicted (TesseractOCR):
# True: THUỐC, Predicted (TesseractOCR): THUOC
# True: VIỆT, Predicted (TesseractOCR): VIET
# True: BẢO, Predicted (TesseractOCR): BAO
# True: Tết, Predicted (TesseractOCR): Tet
# True: sum, Predicted (TesseractOCR): sum
# True: vầy, Predicted (TesseractOCR): vay
# True: đong, Predicted (TesseractOCR): dong
# True: đầy, Predicted (TesseractOCR):
# True: Điểm, Predicted (TesseractOCR): pient
# True: thưởng, Predicted (TesseractOCR):
# True: Chương, Predicted (TesseractOCR):
# True: trình, Predicted (TesseractOCR): trinh
# True: tích, Predicted (TesseractOCR): tich
# True: và, Predicted (TesseractOCR): va
# True: tiêu, Predicted (TesseractOCR): tiéu
# True: điểm, Predicted (TesseractOCR): Diém
# True: thưởng, Predicted (TesseractOCR):
# True: trên, Predicted (TesseractOCR): trén
# True: mỗi, Predicted (TesseractOCR): moi
# True: hoá, Predicted (TesseractOCR):
# True: đơn, Predicted (TesseractOCR): dor
# True: mua, Predicted (TesseractOCR):
# True: hàng, Predicted (TesseractOCR):
# True: ƯỚT, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): BHO
# True: 30, Predicted (TesseractOCR): 30
# True: LƯƠ, Predicted (TesseractOCR): LUC
# True: NHÀ, Predicted (TesseractOCR): : an
# True: THUỐC, Predicted (TesseractOCR):
# True: MỸ, Predicted (TesseractOCR): |
# True: PHẨM, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR): pe
# True: CAO, Predicted (TesseractOCR):
# True: SU, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ###, Predicted (TesseractOCR):
# True: ĐOẠN, Predicted (TesseractOCR):
# True: ĐƯỜNG, Predicted (TesseractOCR):
# True: TỰ, Predicted (TesseractOCR):
# True: QUẢN, Predicted (TesseractOCR):
# True: 2, Predicted (TesseractOCR):
# True: KHÔNG, Predicted (TesseractOCR): KHONG
# [[('HOF', 0.838488757610321)]]
# [[('CHAT', 0.9966933131217957)]]
# [[('LUONG', 0.7583346366882324)]]
# [[('Ti', 0.4364413321018219)]]
# [[('DE', 0.9911088943481445)]]
# [[('CO', 0.8103803396224976)]]
# [[('VIEC', 0.795470118522644)]]
# [[('LAM,', 0.9315711855888367)]]
# [[('NANG', 0.9232258796691895)]]
# [[('SUAT', 0.9528909921646118)]]
# [[('CAO', 0.9881640076637268)]]
# [[('DE', 0.9106793403625488)]]
# [[('TANG', 0.9943826794624329)]]
# [[('THU', 0.9874759316444397)]]
# [[('NHAP', 0.8982211351394653)]]
# [[('am', 0.45274248719215393)]]
# [[('a', 0.08395832031965256)]]
# [[('-', 0.42702555656433105)]]
# [[('-', 0.39139577746391296)]]
# [[('-', 0.39158180356025696)]]
# [[('i', 0.3098796010017395)]]
# [[('2', 0.12732245028018951)]]
# [[('a', 0.2324226349592209)]]
# [[('R', 0.2732454538345337)]]
# [[('E', 0.2811574637889862)]]
# [[('LE', 0.46773743629455566)]]
# [[('O', 0.1279284507036209)]]
# [[('CIEr', 0.43970730900764465)]]
# [[('I', 0.12506745755672455)]]
# [[('SSEE', 0.35921287536621094)]]
# [[('CONG', 0.9965876936912537)]]
# [[('TRUONG', 0.9224962592124939)]]
# [[('AN', 0.9974963068962097)]]
# [[('TOAN', 0.9982101917266846)]]
# [[('GIAO', 0.9925268292427063)]]
# [[('THONG', 0.9980387687683105)]]
# [[('Dung', 0.9844697713851929)]]
# [[('lai', 0.9825563430786133)]]
# [[('quan', 0.9971192479133606)]]
# [[('sat', 0.9961816668510437)]]
# [[('truoc', 0.9925376772880554)]]
# [[('khi', 0.9909138679504395)]]
# [[('enb', 0.9860475659370422)]]
# [[('duong', 0.9984904527664185)]]
# [[('BAN', 0.9630748629570007)]]
# [[('Ngan', 0.7583634853363037)]]
# [[('han', 0.8015078902244568)]]
# [[('VIe', 0.8769526481628418)]]
# [[('Ch', 0.9896555542945862)]]
# [[('LOND', 0.8151801824569702)]]
# [[('IRUONG', 0.7479932308197021)]]
# [[('LANG', 0.7829468846321106)]]
# [[('-', 0.10052555054426193)]]
# [[('LONG', 0.9301952719688416)]]
# [[('CAM', 0.8009805083274841)]]
# [[('od', 0.47362369298934937)]]
# [[('T', 0.6993237733840942)]]
# [[('PAA', 0.26044976711273193)]]
# [[('EAM', 0.6309148669242859)]]
# [[('SE', 0.16892465949058533)]]
# [[('SHE', 0.4075244963169098)]]
# [[('RAO', 0.37269046902656555)]]
# [[('TON', 0.8705129027366638)]]
# [[('OUAY', 0.6253834962844849)]]
# [[('CONO', 0.5655475854873657)]]
# [[('EUONG', 0.6714362502098083)]]
# [[('BAI', 0.9375337958335876)]]
# [[('GU', 0.7482243776321411)]]
# [[('XE', 0.9962923526763916)]]
# [[('HAY', 0.9935972094535828)]]
# [[('NGAN', 0.9974300861358643)]]
# [[('CHAN', 0.9962278008460999)]]
# [[('NAN', 0.9974009394645691)]]
# [[('BUON', 0.996929407119751)]]
# [[('BAN', 0.9965388178825378)]]
# [[('PHU', 0.8553917407989502)]]
# [[('AN', 0.706476092338562)]]
# [[('VA', 0.9904916286468506)]]
# [[('TRE', 0.9957110285758972)]]
# [[('EM', 0.9952834844589233)]]
# [[('KUA', 0.6444456577301025)]]
# [[('DUOC', 0.8162418603897095)]]
# [[('PHARMACY', 0.9973467588424683)]]
# [[('iet', 0.9920948147773743)]]
# [[('Bao', 0.9949899315834045)]]
# [[('Bao', 0.9945221543312073)]]
# [[('Ve', 0.7821959257125854)]]
# [[('suc', 0.9481810927391052)]]
# [[('khoe', 0.9942789673805237)]]
# [[('nguoi', 0.9783248901367188)]]
# [[('Viet', 0.9953482151031494)]]
# [[('DSPT:', 0.973922848701477)]]
# [[('NGUYEN', 0.9969484210014343)]]
# [[('VAN', 0.9887208938598633)]]
# [[('DUNG', 0.9970712661743164)]]
# [[('GPP.', 0.503823459148407)]]
# [[('SC:', 0.7837808132171631)]]
# [[('30', 0.9963847398757935)]]
# [[('LUONG', 0.9803786277770996)]]
# [[('YEN', 0.984623908996582)]]
# [[('8', 0.36395150423049927)]]
# [[('P', 0.9585705399513245)]]
# [[('BACH', 0.9982425570487976)]]
# [[('DANG', 0.9963417053222656)]]
# [[('-', 0.6684291362762451)]]
# [[('Q.', 0.9616798758506775)]]
# [[('HAI', 0.9927288889884949)]]
# [[('BA', 0.9961114525794983)]]
# [[('TRUNG', 0.9758798480033875)]]
# [[('HA', 0.9938449859619141)]]
# [[('NOI', 0.822396457195282)]]
# [[('DT:', 0.8319124579429626)]]
# [[('0968 656003', 0.9418534636497498)]]
# [[('NHA', 0.9948484897613525)]]
# [[('THUOC', 0.9959867596626282)]]
# [[('VIET', 0.9943557977676392)]]
# [[('BAO', 0.9902032017707825)]]
# [[('Tet', 0.9144197106361389)]]
# [[('sum', 0.9974965453147888)]]
# [[('vay', 0.7812336087226868)]]
# [[('dong', 0.9989920854568481)]]
# [[('day', 0.977658748626709)]]
# [[('Dlem', 0.9029543399810791)]]
# [[('thuong', 0.9926319718360901)]]
# [[('chuong', 0.9733586311340332)]]
# [[('trinn', 0.9127860069274902)]]
# [[('tich', 0.959099531173706)]]
# [[('va', 0.6539928913116455)]]
# [[('tleu', 0.8457046151161194)]]
# [[('DlEm', 0.7345961332321167)]]
# [[('thuong', 0.9902140498161316)]]
# [[('tren', 0.9977816343307495)]]
# [[('mol', 0.7616115212440491)]]
# [[('hoa', 0.908161461353302)]]
# [[('don', 0.9894356727600098)]]
# [[('mua', 0.8923308849334717)]]
# [[('hang', 0.9828565120697021)]]
# [[('UOT', 0.9561062455177307)]]
# [[('SAT', 0.8514671921730042)]]
# [[('MHO', 0.8144024014472961)]]
# [[('30', 0.9986815452575684)]]
# [[('LUO', 0.9712188243865967)]]
# [[('M', 0.3885140120983124)]]
# [[('', 0.0)]]
# [[('If', 0.4479871392250061)]]
# [[('PHIy', 0.462397038936615)]]
# [[('io', 0.43813854455947876)]]
# [[('CAO', 0.930533230304718)]]
# [[('SU', 0.8628164529800415)]]
# [[('ef', 0.45392948389053345)]]
# [[('UPN', 0.770266056060791)]]
# [[('PHONG', 0.6825853586196899)]]
# [[('BACH', 0.6844664216041565)]]
# [[('BANE', 0.3790944218635559)]]
# [[('C8', 0.3778139650821686)]]
# [[('o', 0.10912246257066727)]]
# [[('PH', 0.5412973761558533)]]
# [[('W', 0.11640109866857529)]]
# [[('$o', 0.41148650646209717)]]
# [[('3', 0.5087726712226868)]]
# [[('DOAN', 0.9959473013877869)]]
# [[('DUONG', 0.8649983406066895)]]
# [[('TU', 0.9150327444076538)]]
# [[('QUAN', 0.987428605556488)]]
# [[('2', 0.9955601692199707)]]
# [[('KHONG', 0.9956094622612)]]
#    Framework  Avg Runtime (s)  Avg CER (%)  Avg WER (%)  \
# 0    easyocr         0.012484    61.892570    81.927711
# 1  paddleocr         0.038255   100.000000   100.000000
# 2  tesseract         0.105429    81.736948    98.192771
#
#    Exact Match Accuracy (%)
# 0                 19.277108
# 1                  0.000000
# 2                  3.614458
